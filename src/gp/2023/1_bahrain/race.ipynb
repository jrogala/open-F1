# %%
# %cd ../../..
import fastf1
import numpy as np
import pandas as pd
pd.options.display.max_columns = 100

session = fastf1.get_session(2022, 'bahrain', 'R')
fastf1.Cache.enable_cache('../f1cache')
session.load(telemetry=True, laps=True, weather=True)
session.load_telemetry()
# Out:
# /Users/jroga/Documents/f1 stats/src
# api         WARNING
#
# NO CACHE! Api caching has not been enabled!
# 	It is highly recommended to enable this feature for much faster data loading!
# 	Use `fastf1.Cache.enable_cache('path/to/cache/')`
#
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v2.2.9]
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# api            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '55', '44', '63', '20', '77', '31', '22', '14', '24', '47', '18', '23', '3', '4', '6', '27', '11', '1', '10']
# /Users/jroga/Documents/f1 stats/f1thon/lib/python3.9/site-packages/fastf1/core.py:1139: FutureWarning: `Session.load_laps` is deprecated and will beremoved in a future version.
# Use `Session.load` instead.
#   warnings.warn("`Session.load_laps` is deprecated and will be"
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data

# %% [markdown]
# # {Bahrain} Grand Prix 2023
# ## Race information :
# - Date: 5 mars 2023
# - Start time:
# - Laps: 57

# %% [markdown]
# ### Starting grid:

# %%
from modules.display import grid
grid(session)
# Out:
# |---|
#  LEC    |---|
# |---|    VER
#  SAI    |---|
# |---|    PER
#  HAM    |---|
# |---|    BOT
#  MAG    |---|
# |---|    ALO
#  RUS    |---|
# |---|    GAS
#  OCO    |---|
# |---|    MSC
#  NOR    |---|
# |---|    ALB
#  ZHO    |---|
# |---|    TSU
#  HUL    |---|
# |---|    RIC
#  STR    |---|
#          LAT

# %% [markdown]
# ### Starting tyre

# %%
startingTyre = session.laps.query("LapNumber == 1").loc[:, ["Driver", "Compound"]].set_index("Driver")
startingTyre["Driver Name"] = [session.get_driver(name)["FullName"] for name in startingTyre.index]
startingTyre
# Out:
#        Compound       Driver Name
# Driver
# LEC        SOFT   Charles Leclerc
# SAI        SOFT      Carlos Sainz
# HAM        SOFT    Lewis Hamilton
# RUS        SOFT    George Russell
# MAG        SOFT   Kevin Magnussen
# BOT        SOFT   Valtteri Bottas
# OCO        SOFT      Esteban Ocon
# TSU        SOFT      Yuki Tsunoda
# ALO        SOFT   Fernando Alonso
# ZHO        SOFT       Guanyu Zhou
# MSC        SOFT   Mick Schumacher
# STR        SOFT      Lance Stroll
# ALB        SOFT   Alexander Albon
# RIC      MEDIUM  Daniel Ricciardo
# NOR      MEDIUM      Lando Norris
# LAT        SOFT   Nicholas Latifi
# HUL        SOFT   Nico Hulkenberg
# PER        SOFT      Sergio Perez
# VER        SOFT    Max Verstappen
# GAS        SOFT      Pierre Gasly

# %%
session.laps
# Out:
#                        Time DriverNumber                LapTime  LapNumber  \
# 0    0 days 01:04:14.256000           16                    NaT          1
# 1    0 days 01:05:52.109000           16 0 days 00:01:37.853000          2
# 2    0 days 01:07:30.381000           16 0 days 00:01:38.272000          3
# 3    0 days 01:09:08.795000           16 0 days 00:01:38.414000          4
# 4    0 days 01:10:47.266000           16 0 days 00:01:38.471000          5
# ...                     ...          ...                    ...        ...
# 1118 0 days 02:09:55.703000           10 0 days 00:01:38.204000         40
# 1119 0 days 02:11:34.004000           10 0 days 00:01:38.301000         41
# 1120 0 days 02:13:12.333000           10 0 days 00:01:38.329000         42
# 1121 0 days 02:14:50.811000           10 0 days 00:01:38.478000         43
# 1122 0 days 02:16:29.515000           10 0 days 00:01:38.704000         44
#
#       Stint             PitOutTime PitInTime            Sector1Time  \
# 0         1 0 days 00:24:54.765000       NaT                    NaT
# 1         1                    NaT       NaT 0 days 00:00:31.582000
# 2         1                    NaT       NaT 0 days 00:00:31.635000
# 3         1                    NaT       NaT 0 days 00:00:31.619000
# 4         1                    NaT       NaT 0 days 00:00:31.590000
# ...     ...                    ...       ...                    ...
# 1118      3                    NaT       NaT 0 days 00:00:31.492000
# 1119      3                    NaT       NaT 0 days 00:00:31.523000
# 1120      3                    NaT       NaT 0 days 00:00:31.453000
